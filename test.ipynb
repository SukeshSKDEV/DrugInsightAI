# %%
from src.chembl_api import search_target
target=search_target("EGFR")
print(target)
# Out:
# {'target_chembl_id': 'CHEMBL203', 'organism': 'Homo sapiens', 'pref_name': 'Epidermal growth factor receptor'}
